# %%
import string
import pandas as pd
import nltk
import re
from nltk.tokenize import regexp_tokenize
from nltk.corpus import stopwords
from itertools import chain
from gensim.models.doc2vec import TaggedDocument
import numpy as np
from numpy.random import randn
from sklearn.metrics.pairwise import cosine_similarity
import time
import gensim

# %%
tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')

# %%
df_train = pd.read_csv("preprocessed_train_data.csv")

# %%
start_time = time.time()
sentence_1 = df_train['question1']
sentence_2 = df_train['question2']
clean_sentence_1 = df_train['cleaned_question1']
clean_sentence_2 = df_train['cleaned_question2']
sentence_1_english_stopwords = df_train['cleaned_question1_without_english_stopwords']
sentence_2_english_stopwords = df_train['cleaned_question2_without_english_stopwords']
sentence_1_without_stopwords_train = df_train['cleaned_question1_without_stopwords']
sentence_2_without_stopwords_train = df_train['cleaned_question2_without_stopwords']
sentence_1_without_stopwords_test = df_test['cleaned_question1_without_stopwords']
sentence_2_without_stopwords_test = df_test['cleaned_question2_without_stopwords']
is_duplicate = df_train['is_duplicate']
id_ = df_train['index']
qid1 = df_train['qid1']
qid2 = df_train['qid2']
id = df_test['index']

# %%
taggeddocs = []
tag2questionmap = {} 

for c_id, id1 , id2 , q1 , q2, label in zip(id_, qid1, qid2 , sentence_1_without_stopwords_train, sentence_2_without_stopwords_train, is_duplicate):
    questions = [q1, q2]
    try:
        for index,i in enumerate(questions):
            #if len(i) > 2 : # Non empty tweets
            #print i
            if index == 0: 
                tag = u'SENT_{:d}'.format(id1)
            else:
                tag = u'SENT_{:d}'.format(id2)
            sentence = TaggedDocument(words=gensim.utils.to_unicode(i).split(), tags=[tag])
            #print sentence
            tag2questionmap[tag] = i
            taggeddocs.append(sentence)       
    except:
        print c_id
   
    

#model = gensim.models.Doc2Vec(taggeddocs, dm=0, alpha=0.025, size=100, min_alpha=0.025, min_count=2)
model = gensim.models.doc2vec.Doc2Vec(size=100, min_count=2, alpha=0.1)
model.build_vocab(taggeddocs)
# %time model.train(taggeddocs, total_examples=model.corpus_count, epochs=100)
# Out:
# CPU times: user 6min 52s, sys: 2min 23s, total: 9min 16s
# Wall time: 7min 9s
# 73566354

# %%
embedding_1 = []
embedding_2 = []
cos = []
for c_id, q1 , q2 in zip(id_test, sentence_1_without_stopwords_test, sentence_2_without_stopwords_test):  
    questions = [q1, q2]
    embeddings = []

    for index, question in enumerate(questions): 
        if question != question:   #checking for Nan values
            print "c_id: ", c_id
            doc2vec_embed = np.random.uniform(low=-1.0, high=1.0, size=(100,)).reshape(1,-1)
            if index == 0:
                embedding_1.append(doc2vec_embed[0])
            else:
                embedding_2.append(doc2vec_embed[0])
        
        else:
            question_token = tokenizer.tokenize(question)
            doc2vec_embed = model.infer_vector(question_token).reshape(1,-1)
            if index == 0:
                embedding_1.append(doc2vec_embed[0])
            else:
                embedding_2.append(doc2vec_embed[0])
        embeddings.append(doc2vec_embed)
            
    cos.append(cosine_similarity(embeddings[0],embeddings[1])[0])
# Out:
# c_id:  297572
# c_id:  297572
# c_id:  312498
# c_id:  223545

# %%
df_doc2vec = pd.DataFrame()

# %%
df_doc2vec['id'] = id_
df_doc2vec['qid1'] = qid1
df_doc2vec['qid2'] = qid2
df_doc2vec['embedding_1'] = embedding_1
df_doc2vec['embedding_2'] = embedding_2
df_doc2vec['cleaned_question1_without_english_stopwords'] = sentence_1_english_stopwords
df_doc2vec['cleaned_question2_without_english_stopwords'] = sentence_2_english_stopwords
df_doc2vec['is_duplicate'] = is_duplicate
df_doc2vec['cos'] = cos

# %%
df_doc2vec.to_csv("test_doc2vec_english_stopwords.csv")

# %%
df_doc2vec
# Out:
#           id    qid1    qid2  \
# 0     203241  305802  305803
# 1      38884   70554   70555
# 2     106852  175929  122648
# 3     199722  301291  301292
# 4     173172  267202  267203
# 5     184617  151741  282015
# 6      49943   88818   88819
# 7      90591  151993  151994
# 8     385342  517479  517480
# 9     261591  377768  139708
# 10    211754  316665    1382
# 11    132614   81665  212312
# 12    322348  404939   92899
# 13     10427   20201    6171
# 14    129677   49519  208258
# 15    340894  216939  348869
# 16     37029   67442   67443
# 17    348467  477027  477028
# 18     15393   14110   29413
# 19     86404  145739  145740
# 20    319375    5434   26187
# 21    336287   26498   19179
# 22     62041  108209   78286
# 23    224852  333036  333037
# 24    279606  220582  211329
# 25     35288   64512   47392
# 26    219679    8437  132051
# 27    345025   13373   13216
# 28    298937  421497  421498
# 29    348948  477564  146233
# ...      ...     ...     ...
# 9970  333152   22186    1203
# 9971   88777  149264  149265
# 9972  354721  138358  483871
# 9973  135112   20620  215838
# 9974  334344  461513  448002
# 9975  324396  450496  450497
# 9976  200883  146547   39819
# 9977  116044    3240  189118
# 9978  308948  432864  403269
# 9979   72991  125317     177
# 9980  126520  203872  203873
# 9981   76389   55099  112745
# 9982  188046  286460  286461
# 9983  364876  494953  429452
# 9984   24955   46555   46556
# 9985  113325   19657  185246
# 9986  265814  382861  382862
# 9987  133112   13049   24471
# 9988  357045   34202  175982
# 9989   54304   95882   95883
# 9990   63821  110998  110999
# 9991  296147  418303  418304
# 9992  239320  350882  350883
# 9993  211672  316566  316567
# 9994  240559  352398  352399
# 9995  367555  497841  497842
# 9996  393679  526499  526500
# 9997  266818  184009  321106
# 9998  387688  430439  520015
# 9999  238210  349532  349533
#
#                                             embedding_1  \
# 0     [0.0677944, 0.261705, -0.0323886, -0.205037, 0...
# 1     [-0.0717117, -0.088425, 0.138452, 0.247338, -0...
# 2     [-0.105998, 0.0429983, -0.174106, -0.042686, -...
# 3     [0.0268099, 0.170323, 0.0337896, 0.108434, 0.0...
# 4     [0.10813, -0.320954, -0.0200884, -0.112461, -0...
# 5     [0.131546, -0.0239925, 0.0756874, 0.0112747, -...
# 6     [0.137322, 0.0593177, 0.0558565, -0.221473, 0....
# 7     [-0.271313, -0.076802, 0.44095, -0.0780782, -0...
# 8     [0.0854284, 0.100055, -0.207375, -0.174463, 0....
# 9     [0.514061, -0.0217756, 0.225679, 0.162622, -0....
# 10    [0.15091, -0.198866, -0.0945788, 0.129225, 0.0...
# 11    [0.206498, -0.238151, 0.0985362, -0.0134038, 0...
# 12    [-0.1589, -0.021567, 0.124641, 0.0310864, -0.2...
# 13    [-0.00394736, -0.00619979, -0.0431023, -0.0948...
# 14    [-0.0291307, 0.0664712, 0.0784402, 0.095958, 0...
# 15    [-0.127669, 0.0888573, -0.0062485, -0.108517, ...
# 16    [-0.0579481, -0.0571711, 0.00948796, 0.0576947...
# 17    [-0.436383, 0.227174, -0.117149, -0.020674, -0...
# 18    [-0.18043, -0.0948987, -0.106002, -0.156916, -...
# 19    [0.0859286, 0.0252603, -0.153286, 0.0897633, 0...
# 20    [0.0094057, 0.122198, 0.0212261, 0.0311223, 0....
# 21    [0.268313, 0.125493, -0.141628, -0.176518, 0.4...
# 22    [-0.106607, 0.123812, 0.201412, -0.152533, 0.0...
# 23    [-0.00164853, 0.000524526, -0.00139363, -0.000...
# 24    [-0.131784, 0.108677, -0.117256, -0.300575, 0....
# 25    [-0.0698198, 0.0490608, -0.00229644, -0.314153...
# 26    [0.0242381, 0.0381965, -0.246454, -0.0978364, ...
# 27    [-0.173315, -0.15154, 0.227904, -0.167396, -0....
# 28    [0.00133942, 0.0313163, -0.00987541, -0.087172...
# 29    [-0.263801, -0.195332, -0.152989, 0.707873, 0....
# ...                                                 ...
# 9970  [0.0197508, 0.188829, -0.051601, -0.171609, 0....
# 9971  [-0.0422148, 0.100697, -0.0251048, -0.0391842,...
# 9972  [-0.24305, -0.0900889, -0.0310936, -0.185654, ...
# 9973  [0.163069, -0.0283952, -0.235656, -0.183388, 0...
# 9974  [0.0177606, 0.00136496, -0.0255384, -0.128012,...
# 9975  [-0.0704038, 0.120605, -0.221544, -0.131271, -...
# 9976  [-0.0145849, 0.0883023, -0.0857766, -0.111077,...
# 9977  [0.0696089, 0.115671, -0.193667, -0.00592063, ...
# 9978  [-0.00388167, 0.00664389, -0.249407, -0.187751...
# 9979  [0.0969574, -0.0715956, -0.0216834, 0.06641, -...
# 9980  [0.00451697, 0.0203988, -0.0990406, 0.234894, ...
# 9981  [-0.0556396, 0.260617, -0.193682, -0.157613, 0...
# 9982  [-0.361979, 0.212116, 0.045362, 0.250988, 0.11...
# 9983  [0.141304, -0.112229, 0.109368, -0.0171617, 0....
# 9984  [-0.0100719, 0.115816, -0.233229, -0.357278, 0...
# 9985  [0.0123119, -0.0543776, -0.0990917, 0.0628134,...
# 9986  [0.161707, 0.14735, -0.181556, -0.00453867, -0...
# 9987  [0.0162629, 0.0769465, -0.00891405, -0.131173,...
# 9988  [0.00611887, 0.0610578, -0.137342, -0.0605107,...
# 9989  [0.150538, 0.207784, -0.153735, -0.0992443, 0....
# 9990  [-0.369498, 0.220712, 0.350911, 0.323204, -0.7...
# 9991  [-0.0318269, 0.0832169, 0.0917931, -0.317166, ...
# 9992  [-0.0954602, -0.352391, 0.0240036, 0.139353, -...
# 9993  [-0.0122835, -0.0376281, -0.19234, -0.434942, ...
# 9994  [-0.284435, 0.214342, -0.0323793, 0.0124315, 0...
# 9995  [-0.188416, 0.282403, -0.369112, 0.160973, -0....
# 9996  [-0.236978, 0.0661689, -0.281894, -0.177869, -...
# 9997  [0.0960979, 0.00613647, -0.187947, -0.0834204,...
# 9998  [0.362996, 0.179288, -0.140318, -0.172895, -0....
# 9999  [-0.0472224, -0.0880761, -0.0148346, -0.036228...
#
#                                             embedding_2  \
# 0     [-0.0433117, -0.00445305, 0.0152259, -0.235909...
# 1     [0.0756777, -0.0703759, -0.00127475, -0.124583...
# 2     [-0.245069, 0.139701, -0.266468, -0.178425, 0....
# 3     [0.160851, -0.176495, 0.062852, 0.0746028, -0....
# 4     [0.265793, -0.1646, -0.0413023, 0.163308, -0.2...
# 5     [-0.00956149, 0.00824501, -0.0359594, -0.01242...
# 6     [0.103642, 0.0166854, 0.097246, 0.125587, 0.10...
# 7     [-0.0218056, 0.00654468, -0.0188857, -0.037143...
# 8     [0.00114714, -0.0809662, -0.0100761, 0.0469369...
# 9     [0.3123, -0.0736834, 0.245447, 0.17178, -0.177...
# 10    [-0.0236777, -0.0238204, -0.255587, -0.0928861...
# 11    [-0.0192256, 0.0320011, 0.125577, -0.101408, -...
# 12    [-0.0434041, 0.0485148, 0.0518666, -0.0586846,...
# 13    [0.0684252, 0.0607152, -0.138792, -0.0598839, ...
# 14    [-0.0847764, 0.513639, -0.234721, -0.31825, 0....
# 15    [-0.12859, -0.186859, -0.131491, -0.245675, 0....
# 16    [-0.1919, 0.123555, 0.047641, -0.0528766, 0.14...
# 17    [-0.116749, 0.243449, 0.17409, -0.0179607, 0.1...
# 18    [0.157724, 0.206294, -0.202464, -0.0414305, 0....
# 19    [0.220279, 0.311366, -0.105355, -0.164414, -0....
# 20    [-0.0129491, 0.0427466, -0.0221385, -0.0487693...
# 21    [0.0558944, 0.0692379, -0.0408712, -0.0990765,...
# 22    [-0.0918294, -0.22038, 0.0555843, -0.487656, 0...
# 23    [0.00434684, -0.003537, -0.00284369, 0.0007837...
# 24    [0.043895, -0.0166189, -0.350255, -0.422724, 0...
# 25    [-0.0693398, 0.103211, -0.0855862, -0.0222144,...
# 26    [0.268326, 0.221183, -0.382591, -0.0699171, 0....
# 27    [-0.163276, 0.0588085, -0.0987139, -0.0575781,...
# 28    [-0.265061, 0.051782, -0.10351, 0.14746, 0.131...
# 29    [-0.0601983, 0.0465995, 0.199973, -0.070375, -...
# ...                                                 ...
# 9970  [-0.0855746, -0.123535, -0.0679764, -0.203332,...
# 9971  [0.0337913, -0.00278484, -0.0362699, -0.006317...
# 9972  [-0.0350123, -0.0816049, 0.0316629, 0.0799208,...
# 9973  [0.278414, 0.268551, 0.000251973, 0.15795, 0.0...
# 9974  [-0.0483453, 0.0619836, -0.0495509, -0.156385,...
# 9975  [-0.0181654, -0.111294, -0.00868684, 0.168299,...
# 9976  [0.0309967, 0.0636279, -0.0378965, -0.0347343,...
# 9977  [-0.545962, 0.36095, 0.176443, 0.10081, -0.185...
# 9978  [0.174797, 0.167448, -0.222688, -0.0100314, 0....
# 9979  [0.0437111, 0.00898331, -0.0414956, -0.0706754...
# 9980  [-0.313161, -0.0141908, -0.388064, 0.290684, 0...
# 9981  [0.139566, -0.0426906, -0.0905961, -0.0284787,...
# 9982  [0.304077, 0.180671, 0.0507779, -0.121318, -0....
# 9983  [0.340469, -0.277028, 0.859324, -0.082074, -0....
# 9984  [0.131086, 0.179753, -0.0992428, -0.11072, -0....
# 9985  [0.012008, 0.0336571, -0.023681, 0.00674483, 0...
# 9986  [-0.0464693, 0.131755, -0.253602, -0.132692, -...
# 9987  [0.0238035, 0.106639, 0.00590091, -0.148548, 0...
# 9988  [0.0522405, 0.172392, -0.108816, -0.0719742, 0...
# 9989  [-0.0793705, -0.00994101, 0.164131, 0.0285533,...
# 9990  [-0.0770423, -0.0250499, 0.0253368, 0.184981, ...
# 9991  [-0.028967, -0.121733, -0.0114435, -0.20343, 0...
# 9992  [0.0716957, -0.0202523, 0.447247, -0.0401134, ...
# 9993  [0.0503538, -0.0800346, 0.0950783, 0.0916179, ...
# 9994  [-0.0609102, -0.187975, 0.257823, 0.456633, 0....
# 9995  [-0.0435249, 0.0931745, -0.0197595, 0.0418459,...
# 9996  [0.162049, -0.0987225, 0.0438474, 0.00737411, ...
# 9997  [0.0789085, 0.069655, -0.054257, -0.08346, -0....
# 9998  [0.143733, 0.105946, -0.208558, -0.258652, -0....
# 9999  [-0.0483939, 0.196983, -0.0711232, -0.278677, ...
#
#             cleaned_question1_without_english_stopwords  \
# 0           think book  brave new world  aldous huxley
# 1               behind coup attempt turkey  july 2016
# 2                                     based real event
# 3                          wallet transfer limit paytm
# 4                         gta 5 available android also
# 5     suitable inpatient drug alcohol rehab center p...
# 6              hand salary iocl officer grade  7th pay
# 7     electricity solely dependent copper carbon fri...
# 8                      delete installed update android
# 9                                       alone universe
# 10               access specifier access modifier java
# 11                            sun space  universe dark
# 12                          good bml munjal university
# 13                          way make money online home
# 14                 seen acceptable racist white people
# 15      cow responsible 20 time human death year shark
# 16                                    sad song english
# 17                                      love boyfriend
# 18    ban 500 1000 rupee note help identify black mo...
# 19                                  best lie ever spun
# 20    safety precaution handling shotgun proposed nr...
# 21            would vote  donald trump hillary clinton
# 22    point popular vote united state electoral coll...
# 23                       alcl3 covalent ionic compound
# 24                         best way market android app
# 25                            one stay motivated happy
# 26                                 buy used rental car
# 27         view move scrap 500 1000 rupee note  effect
# 28    best fried chicken wing recipe without flour  ...
# 29    dad hate cannot wait till move neither 14 hars...
# ...                                                 ...
# 9970                    best hilarious joke ever heard
# 9971                                 texas leave union
# 9972  physical meaning divergence  curl gradient vec...
# 9973                  correct   bare mind   bear mind
# 9974              best country job mechanical engineer
# 9975                      much cost studying m germany
# 9976  question keep getting marked needing improvement
# 9977  thich quang duc able burn death without moving...
# 9978                   long take answer question Quora
# 9979  best laptop r  60000 India running latest pira...
# 9980                          discovered egypt pyramid
# 9981               would stratify preparation cat 2017
# 9982      high could cat fall onto hard ground injured
# 9983        bank statement good address proof passport
# 9984                                          retailer
# 9985                 develop photographic memory skill
# 9986                                  best way sex car
# 9987                             lose body fat quickly
# 9988              likely democratic candidate run 2020
# 9989       best response someone call terrorist muslim
# 9990  final year cse student know coding non coding ...
# 9991                  common perception China disagree
# 9992                     find sp cp x gain rs4 percent
# 9993             sexually assaulted  even friend drunk
# 9994  use homemade laundry detergent high efficiency...
# 9995       successful european e commerce company date
# 9996                                          ufo work
# 9997                                  rent bike mumbai
# 9998  difference intel core  core  atom  celeron pen...
# 9999                     happens hikikomori parent die
#
#             cleaned_question2_without_english_stopwords  is_duplicate  \
# 0                gamma  brave new world  aldous huxley              0
# 1                            likely behind turkey coup              1
# 2                                  g  based real event              0
# 3            working experience ma gofrugal technology              0
# 4                              gta 5 available android              1
# 5     suitable inpatient drug alcohol rehab center h...             0
# 6        gross salary agm bpcl iocl 7th pay commission              0
# 7                         friction depend surface area              0
# 8                     updating android o reduce memory              0
# 9                                       alone universe              1
# 10                                access modifier java              0
# 11                                          space dark              1
# 12                          good bml munjal university              1
# 13                earn money online without investment              1
# 14    ok Quora user call racist reason  ok say possi...             1
# 15     cow responsible 20 time human death year shark               1
# 16                                    sad song english              1
# 17                               cannot love boyfriend              1
# 18    issuing new 2000 r note help curb black money ...             1
# 19                          best crafted lie ever told              1
# 20    safety precaution handling shotgun proposed nr...             1
# 21                       donald trump hillary clinton               1
# 22    meaning popular vote united state electoral co...             1
# 23                                 nbr3 ionic covalent              0
# 24                                  market android app              1
# 25                self improvement  motivate work hard              0
# 26            good idea buy used car car rental agency              1
# 27            think rbi new move banning 500 1000 note              1
# 28                             good side chicken strip              0
# 29    11 dad really mean emotionally abusive  mum an...             0
# ...                                                 ...           ...
# 9970                  funniest joke   story ever heard              1
# 9971                              texas secede legally              1
# 9972                 meaning divergence  curl gradiant              1
# 9973                            word mean  mind fully               0
# 9974           best country job mechanical engineering              1
# 9975     much cost m mechanical germany 2016  2018 inr              1
# 9976    question repeatedly marked needing improvement              1
# 9977   true chicken still move without head brain head              0
# 9978                 long take question answered Quora              0
# 9979                      best gaming laptop 60000 inr              1
# 9980  jewish people claim ownership pyramid egypt  r...             0
# 9981                                 strategy cat 2017              1
# 9982                         fall plane die hit ground              0
# 9983  bank account passbook address proof 1 year tra...             0
# 9984                                          retailer              1
# 9985                       develop photographic memory              1
# 9986                                      sex done car              1
# 9987                          could lose pound quickly              1
# 9988                     democrat could run trump 2020              1
# 9989  marry someone federal clawback earnings scamme...             0
# 9990  merge multiple excel file one workbook differe...             0
# 9991                  common perception China disagree              1
# 9992  college graduate expect prepare trump presidency              0
# 9993                     still sexual harassment drunk              1
# 9994  use high efficiency   laundry detergent normal...             0
# 9995                         hot e commerce company uk              0
# 9996                                           ufo fly              1
# 9997                              get bike rent mumbai              1
# 9998               good amd series quad core processor              0
# 9999                           like sibling hikikomori              0
#
#                 cos
# 0        [0.404644]
# 1        [0.188688]
# 2        [0.576933]
# 3      [-0.0382312]
# 4        [0.679803]
# 5         [0.14497]
# 6        [0.032714]
# 7       [-0.405582]
# 8        [0.173189]
# 9        [0.657439]
# 10       [0.334554]
# 11      [0.0461125]
# 12       [0.734973]
# 13       [0.436074]
# 14      [0.0385701]
# 15       [0.335425]
# 16       [0.373543]
# 17       [0.631316]
# 18       [0.360928]
# 19       [0.312108]
# 20       [0.633316]
# 21       [0.748237]
# 22       [0.321614]
# 23      [0.0240898]
# 24       [0.223985]
# 25       [0.205138]
# 26       [0.652603]
# 27      [0.0854268]
# 28       [0.132697]
# 29    [-0.00464108]
# ...             ...
# 9970     [0.245058]
# 9971    [-0.239176]
# 9972   [-0.0250324]
# 9973   [-0.0147158]
# 9974     [0.636817]
# 9975     [0.012886]
# 9976     [0.778513]
# 9977   [0.00452121]
# 9978     [0.350245]
# 9979    [-0.303151]
# 9980     [0.171507]
# 9981     [0.654748]
# 9982    [0.0530477]
# 9983    [0.0459227]
# 9984     [0.645652]
# 9985   [0.00510582]
# 9986   [-0.0644421]
# 9987     [0.461175]
# 9988      [0.65456]
# 9989   [-0.0702973]
# 9990   [-0.0578232]
# 9991     [0.272263]
# 9992    [-0.154448]
# 9993    [-0.336598]
# 9994     [0.321534]
# 9995    [-0.139706]
# 9996    [-0.397556]
# 9997     [0.437401]
# 9998     [0.474897]
# 9999     [0.422322]
#
# [10000 rows x 9 columns]
